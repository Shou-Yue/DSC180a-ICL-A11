# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
from icl_classification.gemma import run_single_experiment

# %%
from huggingface_hub import login
login()

# %%
d, B, steps, label_flip_p = 1000, 10, 300, 0.2
R = d ** 0.1
params = (d, B, R, R, steps, label_flip_p)
_, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results_gpt/", use_cuda=False)
