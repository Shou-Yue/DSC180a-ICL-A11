# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
from gpt import run_single_experiment
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
d, B, steps, label_flip_p = 1000, 10, 300, 0.2
R = d ** 0.1
params = (d, B, R, R, steps, label_flip_p)
_, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results_gpt/", use_cuda=False)
# Out:
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 10
# Validation tasks: 50
# Batch size: 10
# --------------------------------------------------
# Step 0/300 | Train Loss: 1.1596 | Train Acc: 0.5000 | Val Loss: 9.7458 | Val Acc: 0.7000 | In-context Acc: 0.4500 | Batch time: 1200.65ms | Samples/sec: 8.33
# Step 100/300 | Train Loss: 0.0021 | Train Acc: 1.0000 | Val Loss: 1.2159 | Val Acc: 0.7000 | In-context Acc: 0.4500 | Batch time: 531.28ms | Samples/sec: 18.12
# Step 200/300 | Train Loss: 0.0007 | Train Acc: 1.0000 | Val Loss: 1.4393 | Val Acc: 0.7000 | In-context Acc: 0.4500 | Batch time: 549.55ms | Samples/sec: 18.21
#
# Training completed!
# Total training time: 164.94 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7000
# Final in-context accuracy: 0.4500
# Average samples/second: 18.19
# Average batch time: 549.69ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B10_R1_20251124_151933_step_300.pt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       3 params = (d, B, R, R, steps, label_flip_p)
#       4 _, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results_gpt/", use_cuda=False)
# ----> 5 train_accs.append(train_acc)
#       6 val_accs.append(val_acc)
#       7 ic_accs.append(ic_acc)
#
# NameError: name 'train_accs' is not defined

# %%
d, B, steps, label_flip_p = 1000, 10, 300, 0.2
R = d ** 0.3
params = (d, B, R, R, steps, label_flip_p)
_, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results_gpt/", use_cuda=False)
# Out:
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 826d0471-0ca0-4428-a4d9-25347be25924)')' thrown while requesting HEAD https://huggingface.co/gpt2/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 10
# Validation tasks: 50
# Batch size: 10
# --------------------------------------------------
# Step 0/300 | Train Loss: 1.6622 | Train Acc: 0.4000 | Val Loss: 33.8114 | Val Acc: 0.3000 | In-context Acc: 0.5500 | Batch time: 667.96ms | Samples/sec: 14.97
# Step 100/300 | Train Loss: 0.2839 | Train Acc: 0.9000 | Val Loss: 1.1428 | Val Acc: 0.3000 | In-context Acc: 0.5500 | Batch time: 540.71ms | Samples/sec: 18.40
# Step 200/300 | Train Loss: 0.0395 | Train Acc: 1.0000 | Val Loss: 2.0540 | Val Acc: 0.3000 | In-context Acc: 0.5500 | Batch time: 534.00ms | Samples/sec: 18.33
#
# Training completed!
# Total training time: 164.29 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.3000
# Final in-context accuracy: 0.5500
# Average samples/second: 18.26
# Average batch time: 547.51ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B10_R7_20251124_152232_step_300.pt

# %%
d, B, steps, label_flip_p = 1000, 10, 300, 0.2
R = d ** 0.6
params = (d, B, R, R, steps, label_flip_p)
_, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results_gpt/", use_cuda=False)
# Out:
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 10
# Validation tasks: 50
# Batch size: 10
# --------------------------------------------------
# Step 0/300 | Train Loss: 1.5294 | Train Acc: 0.4000 | Val Loss: 56.0487 | Val Acc: 0.3000 | In-context Acc: 0.5500 | Batch time: 654.44ms | Samples/sec: 15.27
# Step 100/300 | Train Loss: 0.0011 | Train Acc: 1.0000 | Val Loss: 1.1415 | Val Acc: 0.4000 | In-context Acc: 0.5500 | Batch time: 566.50ms | Samples/sec: 17.69
# Step 200/300 | Train Loss: 0.0004 | Train Acc: 1.0000 | Val Loss: 1.1399 | Val Acc: 0.5000 | In-context Acc: 0.5500 | Batch time: 575.71ms | Samples/sec: 17.75
#
# Training completed!
# Total training time: 170.04 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.5000
# Final in-context accuracy: 0.5500
# Average samples/second: 17.64
# Average batch time: 566.67ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B10_R63_20251124_152531_step_300.pt

# %%
d, B, steps, label_flip_p = 1000, 100, 300, 0.2
R = d ** 0.6
params = (d, B, R, R, steps, label_flip_p)
_, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results_gpt/", use_cuda=False)
# Out:
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 1.3086 | Train Acc: 0.4600 | Val Loss: 29.2424 | Val Acc: 0.5000 | In-context Acc: 0.5000 | Batch time: 6475.80ms | Samples/sec: 15.44
