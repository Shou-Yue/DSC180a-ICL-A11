# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
from classification_icl import run_single_experiment
# Out:
# /Users/sebastianleng/miniforge3/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /Users/sebastianleng/miniforge3/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %%
ds = [10, 20, 50, 100, 200, 500, 800, 1000]
train_accs = []
val_accs = []
ic_accs = []

for d in ds:
    B, steps, label_flip_p = 100, 300, 0.2
    R = d ** 0.1
    params = (d, B, R, R, steps, label_flip_p)
    _, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results/", use_cuda=False)
    train_accs.append(train_acc)
    val_accs.append(val_acc)
    ic_accs.append(ic_acc)
# Out:
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 10
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4500 | Val Loss: 0.6929 | Val Acc: 0.7100 | In-context Acc: 0.7180 | Batch time: 9.23ms | Samples/sec: 10438.27
# Step 100/300 | Train Loss: 0.5906 | Train Acc: 0.9400 | Val Loss: 0.6721 | Val Acc: 0.7100 | In-context Acc: 0.7193 | Batch time: 0.36ms | Samples/sec: 205789.91
# Step 200/300 | Train Loss: 0.5178 | Train Acc: 0.9500 | Val Loss: 0.6567 | Val Acc: 0.7100 | In-context Acc: 0.7190 | Batch time: 0.37ms | Samples/sec: 225964.40
#
# Training completed!
# Total training time: 0.13 seconds
# Final train accuracy: 0.9500
# Final validation accuracy: 0.7100
# Final in-context accuracy: 0.7195
# Average samples/second: 232426.78
# Average batch time: 0.40ms
# Saving checkpoint at checkpoints/checkpoint_d10_B100_R1_20251124_145646_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 20
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 0.6930 | Val Acc: 0.6100 | In-context Acc: 0.6862 | Batch time: 0.48ms | Samples/sec: 174182.06
# Step 100/300 | Train Loss: 0.5694 | Train Acc: 0.9800 | Val Loss: 0.6794 | Val Acc: 0.6100 | In-context Acc: 0.6915 | Batch time: 0.39ms | Samples/sec: 243192.73
# Step 200/300 | Train Loss: 0.4816 | Train Acc: 0.9800 | Val Loss: 0.6688 | Val Acc: 0.6100 | In-context Acc: 0.6890 | Batch time: 0.38ms | Samples/sec: 241743.16
#
# Training completed!
# Total training time: 0.12 seconds
# Final train accuracy: 0.9800
# Final validation accuracy: 0.6100
# Final in-context accuracy: 0.6877
# Average samples/second: 241252.54
# Average batch time: 0.38ms
# Saving checkpoint at checkpoints/checkpoint_d20_B100_R1_20251124_145646_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 50
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4400 | Val Loss: 0.6931 | Val Acc: 0.5400 | In-context Acc: 0.6198 | Batch time: 0.55ms | Samples/sec: 158995.60
# Step 100/300 | Train Loss: 0.3815 | Train Acc: 1.0000 | Val Loss: 0.6872 | Val Acc: 0.5400 | In-context Acc: 0.6220 | Batch time: 0.41ms | Samples/sec: 227401.89
# Step 200/300 | Train Loss: 0.2515 | Train Acc: 1.0000 | Val Loss: 0.6851 | Val Acc: 0.5400 | In-context Acc: 0.6223 | Batch time: 0.40ms | Samples/sec: 225718.77
#
# Training completed!
# Total training time: 0.13 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.5400
# Final in-context accuracy: 0.6248
# Average samples/second: 225693.15
# Average batch time: 0.41ms
# Saving checkpoint at checkpoints/checkpoint_d50_B100_R1_20251124_145646_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 100
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4200 | Val Loss: 0.6930 | Val Acc: 0.5300 | In-context Acc: 0.5872 | Batch time: 0.94ms | Samples/sec: 96709.80
# Step 100/300 | Train Loss: 0.1969 | Train Acc: 1.0000 | Val Loss: 0.6865 | Val Acc: 0.5200 | In-context Acc: 0.5853 | Batch time: 0.74ms | Samples/sec: 134296.02
# Step 200/300 | Train Loss: 0.1061 | Train Acc: 1.0000 | Val Loss: 0.6851 | Val Acc: 0.5200 | In-context Acc: 0.5850 | Batch time: 0.92ms | Samples/sec: 134922.93
#
# Training completed!
# Total training time: 0.22 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.5200
# Final in-context accuracy: 0.5857
# Average samples/second: 136505.19
# Average batch time: 0.70ms
# Saving checkpoint at checkpoints/checkpoint_d100_B100_R1_20251124_145647_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 200
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 0.6933 | Val Acc: 0.4700 | In-context Acc: 0.5440 | Batch time: 1.81ms | Samples/sec: 52083.75
# Step 100/300 | Train Loss: 0.0679 | Train Acc: 1.0000 | Val Loss: 0.7006 | Val Acc: 0.4600 | In-context Acc: 0.5443 | Batch time: 1.01ms | Samples/sec: 64869.94
# Step 200/300 | Train Loss: 0.0336 | Train Acc: 1.0000 | Val Loss: 0.7032 | Val Acc: 0.4700 | In-context Acc: 0.5458 | Batch time: 1.51ms | Samples/sec: 68248.48
#
# Training completed!
# Total training time: 0.43 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.4700
# Final in-context accuracy: 0.5452
# Average samples/second: 69731.09
# Average batch time: 1.40ms
# Saving checkpoint at checkpoints/checkpoint_d200_B100_R1_20251124_145647_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 500
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4500 | Val Loss: 0.6931 | Val Acc: 0.5000 | In-context Acc: 0.5280 | Batch time: 3.93ms | Samples/sec: 24889.06
# Step 100/300 | Train Loss: 0.0130 | Train Acc: 1.0000 | Val Loss: 0.6929 | Val Acc: 0.5200 | In-context Acc: 0.5310 | Batch time: 3.28ms | Samples/sec: 30120.20
# Step 200/300 | Train Loss: 0.0065 | Train Acc: 1.0000 | Val Loss: 0.6930 | Val Acc: 0.5200 | In-context Acc: 0.5318 | Batch time: 3.82ms | Samples/sec: 29836.48
#
# Training completed!
# Total training time: 1.02 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.5200
# Final in-context accuracy: 0.5318
# Average samples/second: 29340.97
# Average batch time: 3.35ms
# Saving checkpoint at checkpoints/checkpoint_d500_B100_R1_20251124_145647_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 800
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5000 | Val Loss: 0.6936 | Val Acc: 0.4400 | In-context Acc: 0.5010 | Batch time: 5.52ms | Samples/sec: 17777.75
# Step 100/300 | Train Loss: 0.0052 | Train Acc: 1.0000 | Val Loss: 0.6958 | Val Acc: 0.4400 | In-context Acc: 0.4985 | Batch time: 4.25ms | Samples/sec: 22887.91
# Step 200/300 | Train Loss: 0.0026 | Train Acc: 1.0000 | Val Loss: 0.6962 | Val Acc: 0.4400 | In-context Acc: 0.4988 | Batch time: 4.91ms | Samples/sec: 22973.03
#
# Training completed!
# Total training time: 1.30 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.4500
# Final in-context accuracy: 0.4990
# Average samples/second: 23071.44
# Average batch time: 4.25ms
# Saving checkpoint at checkpoints/checkpoint_d800_B100_R1_20251124_145649_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5500 | Val Loss: 0.6927 | Val Acc: 0.5500 | In-context Acc: 0.5222 | Batch time: 6.17ms | Samples/sec: 15972.22
# Step 100/300 | Train Loss: 0.0034 | Train Acc: 1.0000 | Val Loss: 0.6920 | Val Acc: 0.5600 | In-context Acc: 0.5228 | Batch time: 6.09ms | Samples/sec: 16276.14
# Step 200/300 | Train Loss: 0.0017 | Train Acc: 1.0000 | Val Loss: 0.6919 | Val Acc: 0.5600 | In-context Acc: 0.5232 | Batch time: 5.78ms | Samples/sec: 16635.00
#
# Training completed!
# Total training time: 1.79 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.5600
# Final in-context accuracy: 0.5230
# Average samples/second: 16714.13
# Average batch time: 5.89ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B100_R1_20251124_145650_step_300.pt

# %%
plt.figure(figsize=(8, 5))

plt.plot(ds, train_accs, marker='o', label="Train Acc")
plt.plot(ds, val_accs, marker='o', label="Val Acc")
plt.plot(ds, ic_accs, marker='o', label="In-context Acc")

plt.xlabel("Dimension d")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Input Dimension: R = d^0.1")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
ds = [10, 20, 50, 100, 200, 500, 800, 1000]
train_accs = []
val_accs = []
ic_accs = []

for d in ds:
    B, steps, label_flip_p = 100, 300, 0.2
    R = d ** 0.3
    params = (d, B, R, R, steps, label_flip_p)
    _, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results/", use_cuda=False)
    train_accs.append(train_acc)
    val_accs.append(val_acc)
    ic_accs.append(ic_acc)
# Out:
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 10
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4900 | Val Loss: 0.6919 | Val Acc: 0.7900 | In-context Acc: 0.7853 | Batch time: 0.89ms | Samples/sec: 90982.73
# Step 100/300 | Train Loss: 0.3870 | Train Acc: 1.0000 | Val Loss: 0.6213 | Val Acc: 0.8100 | In-context Acc: 0.7890 | Batch time: 0.37ms | Samples/sec: 236882.85
# Step 200/300 | Train Loss: 0.2797 | Train Acc: 1.0000 | Val Loss: 0.5965 | Val Acc: 0.8200 | In-context Acc: 0.7895 | Batch time: 0.37ms | Samples/sec: 244041.95
#
# Training completed!
# Total training time: 0.12 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8200
# Final in-context accuracy: 0.7905
# Average samples/second: 246160.01
# Average batch time: 0.38ms
# Saving checkpoint at checkpoints/checkpoint_d10_B100_R1_20251124_145652_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 20
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 0.6913 | Val Acc: 0.8100 | In-context Acc: 0.7895 | Batch time: 0.42ms | Samples/sec: 198876.43
# Step 100/300 | Train Loss: 0.2972 | Train Acc: 1.0000 | Val Loss: 0.5896 | Val Acc: 0.8100 | In-context Acc: 0.7908 | Batch time: 0.39ms | Samples/sec: 246481.16
# Step 200/300 | Train Loss: 0.1826 | Train Acc: 1.0000 | Val Loss: 0.5512 | Val Acc: 0.8200 | In-context Acc: 0.7905 | Batch time: 0.39ms | Samples/sec: 242844.79
#
# Training completed!
# Total training time: 0.12 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8300
# Final in-context accuracy: 0.7897
# Average samples/second: 241986.52
# Average batch time: 0.38ms
# Saving checkpoint at checkpoints/checkpoint_d20_B100_R2_20251124_145652_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 50
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4400 | Val Loss: 0.6913 | Val Acc: 0.7300 | In-context Acc: 0.7850 | Batch time: 0.54ms | Samples/sec: 161071.58
# Step 100/300 | Train Loss: 0.1160 | Train Acc: 1.0000 | Val Loss: 0.6272 | Val Acc: 0.7300 | In-context Acc: 0.7870 | Batch time: 0.42ms | Samples/sec: 224354.91
# Step 200/300 | Train Loss: 0.0590 | Train Acc: 1.0000 | Val Loss: 0.6118 | Val Acc: 0.7300 | In-context Acc: 0.7880 | Batch time: 0.41ms | Samples/sec: 224603.87
#
# Training completed!
# Total training time: 0.13 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7300
# Final in-context accuracy: 0.7875
# Average samples/second: 224815.29
# Average batch time: 0.41ms
# Saving checkpoint at checkpoints/checkpoint_d50_B100_R3_20251124_145652_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 100
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4200 | Val Loss: 0.6911 | Val Acc: 0.7100 | In-context Acc: 0.7682 | Batch time: 1.45ms | Samples/sec: 65108.72
# Step 100/300 | Train Loss: 0.0454 | Train Acc: 1.0000 | Val Loss: 0.6527 | Val Acc: 0.7100 | In-context Acc: 0.7685 | Batch time: 0.86ms | Samples/sec: 103047.63
# Step 200/300 | Train Loss: 0.0224 | Train Acc: 1.0000 | Val Loss: 0.6462 | Val Acc: 0.7100 | In-context Acc: 0.7680 | Batch time: 0.81ms | Samples/sec: 104569.25
#
# Training completed!
# Total training time: 0.29 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7100
# Final in-context accuracy: 0.7685
# Average samples/second: 104990.59
# Average batch time: 0.92ms
# Saving checkpoint at checkpoints/checkpoint_d100_B100_R3_20251124_145653_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 200
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 0.6910 | Val Acc: 0.6500 | In-context Acc: 0.7582 | Batch time: 2.01ms | Samples/sec: 47576.04
# Step 100/300 | Train Loss: 0.0152 | Train Acc: 1.0000 | Val Loss: 0.6686 | Val Acc: 0.6600 | In-context Acc: 0.7548 | Batch time: 1.53ms | Samples/sec: 64934.67
# Step 200/300 | Train Loss: 0.0076 | Train Acc: 1.0000 | Val Loss: 0.6651 | Val Acc: 0.6600 | In-context Acc: 0.7548 | Batch time: 1.97ms | Samples/sec: 63483.83
#
# Training completed!
# Total training time: 0.47 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.6600
# Final in-context accuracy: 0.7550
# Average samples/second: 63905.25
# Average batch time: 1.53ms
# Saving checkpoint at checkpoints/checkpoint_d200_B100_R4_20251124_145653_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 500
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4500 | Val Loss: 0.6898 | Val Acc: 0.6200 | In-context Acc: 0.7035 | Batch time: 3.81ms | Samples/sec: 25562.55
# Step 100/300 | Train Loss: 0.0034 | Train Acc: 1.0000 | Val Loss: 0.6808 | Val Acc: 0.6300 | In-context Acc: 0.7010 | Batch time: 2.84ms | Samples/sec: 28727.78
# Step 200/300 | Train Loss: 0.0017 | Train Acc: 1.0000 | Val Loss: 0.6795 | Val Acc: 0.6300 | In-context Acc: 0.7010 | Batch time: 3.78ms | Samples/sec: 28545.63
#
# Training completed!
# Total training time: 1.05 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.6300
# Final in-context accuracy: 0.7010
# Average samples/second: 28571.57
# Average batch time: 3.44ms
# Saving checkpoint at checkpoints/checkpoint_d500_B100_R6_20251124_145653_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 800
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5000 | Val Loss: 0.6898 | Val Acc: 0.6000 | In-context Acc: 0.6528 | Batch time: 4.34ms | Samples/sec: 22551.23
# Step 100/300 | Train Loss: 0.0015 | Train Acc: 1.0000 | Val Loss: 0.6866 | Val Acc: 0.5800 | In-context Acc: 0.6505 | Batch time: 4.00ms | Samples/sec: 23801.99
# Step 200/300 | Train Loss: 0.0008 | Train Acc: 1.0000 | Val Loss: 0.6860 | Val Acc: 0.5800 | In-context Acc: 0.6505 | Batch time: 4.17ms | Samples/sec: 23854.96
#
# Training completed!
# Total training time: 1.26 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.5800
# Final in-context accuracy: 0.6500
# Average samples/second: 23876.79
# Average batch time: 4.11ms
# Saving checkpoint at checkpoints/checkpoint_d800_B100_R7_20251124_145655_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5500 | Val Loss: 0.6875 | Val Acc: 0.6100 | In-context Acc: 0.6690 | Batch time: 5.63ms | Samples/sec: 17485.74
# Step 100/300 | Train Loss: 0.0009 | Train Acc: 1.0000 | Val Loss: 0.6851 | Val Acc: 0.6100 | In-context Acc: 0.6695 | Batch time: 5.60ms | Samples/sec: 17581.09
# Step 200/300 | Train Loss: 0.0005 | Train Acc: 1.0000 | Val Loss: 0.6844 | Val Acc: 0.6200 | In-context Acc: 0.6693 | Batch time: 5.43ms | Samples/sec: 17662.43
#
# Training completed!
# Total training time: 1.70 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.6200
# Final in-context accuracy: 0.6693
# Average samples/second: 17680.20
# Average batch time: 5.57ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B100_R7_20251124_145656_step_300.pt

# %%
plt.figure(figsize=(8, 5))

plt.plot(ds, train_accs, marker='o', label="Train Acc")
plt.plot(ds, val_accs, marker='o', label="Val Acc")
plt.plot(ds, ic_accs, marker='o', label="In-context Acc")

plt.xlabel("Dimension d")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Input Dimension: R = d^0.3")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
ds = [10, 20, 50, 100, 200, 500, 800, 1000]
train_accs = []
val_accs = []
ic_accs = []

for d in ds:
    B, steps, label_flip_p = 100, 300, 0.2
    R = d ** 0.4
    params = (d, B, R, R, steps, label_flip_p)
    _, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results/", use_cuda=False)
    train_accs.append(train_acc)
    val_accs.append(val_acc)
    ic_accs.append(ic_acc)
# Out:
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 10
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4900 | Val Loss: 0.6899 | Val Acc: 0.8200 | In-context Acc: 0.7952 | Batch time: 0.54ms | Samples/sec: 137925.16
# Step 100/300 | Train Loss: 0.2397 | Train Acc: 1.0000 | Val Loss: 0.5722 | Val Acc: 0.8200 | In-context Acc: 0.7955 | Batch time: 0.38ms | Samples/sec: 240751.94
# Step 200/300 | Train Loss: 0.1518 | Train Acc: 1.0000 | Val Loss: 0.5545 | Val Acc: 0.8200 | In-context Acc: 0.7958 | Batch time: 0.36ms | Samples/sec: 243353.00
#
# Training completed!
# Total training time: 0.12 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8200
# Final in-context accuracy: 0.7955
# Average samples/second: 244729.94
# Average batch time: 0.38ms
# Saving checkpoint at checkpoints/checkpoint_d10_B100_R2_20251124_145658_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 20
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 0.6872 | Val Acc: 0.8400 | In-context Acc: 0.7952 | Batch time: 0.60ms | Samples/sec: 144981.13
# Step 100/300 | Train Loss: 0.1329 | Train Acc: 1.0000 | Val Loss: 0.5115 | Val Acc: 0.8400 | In-context Acc: 0.7950 | Batch time: 0.38ms | Samples/sec: 239149.54
# Step 200/300 | Train Loss: 0.0702 | Train Acc: 1.0000 | Val Loss: 0.4871 | Val Acc: 0.8400 | In-context Acc: 0.7947 | Batch time: 0.38ms | Samples/sec: 241201.61
#
# Training completed!
# Total training time: 0.12 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8400
# Final in-context accuracy: 0.7947
# Average samples/second: 241884.65
# Average batch time: 0.38ms
# Saving checkpoint at checkpoints/checkpoint_d20_B100_R3_20251124_145658_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 50
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4400 | Val Loss: 0.6847 | Val Acc: 0.7500 | In-context Acc: 0.8048 | Batch time: 0.49ms | Samples/sec: 174762.67
# Step 100/300 | Train Loss: 0.0382 | Train Acc: 1.0000 | Val Loss: 0.5715 | Val Acc: 0.7500 | In-context Acc: 0.8050 | Batch time: 0.40ms | Samples/sec: 225364.66
# Step 200/300 | Train Loss: 0.0189 | Train Acc: 1.0000 | Val Loss: 0.5630 | Val Acc: 0.7500 | In-context Acc: 0.8050 | Batch time: 0.40ms | Samples/sec: 224575.15
#
# Training completed!
# Total training time: 0.13 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7500
# Final in-context accuracy: 0.8050
# Average samples/second: 225551.55
# Average batch time: 0.41ms
# Saving checkpoint at checkpoints/checkpoint_d50_B100_R4_20251124_145658_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 100
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4200 | Val Loss: 0.6818 | Val Acc: 0.7500 | In-context Acc: 0.7980 | Batch time: 1.23ms | Samples/sec: 76163.14
# Step 100/300 | Train Loss: 0.0138 | Train Acc: 1.0000 | Val Loss: 0.6051 | Val Acc: 0.7400 | In-context Acc: 0.7970 | Batch time: 1.04ms | Samples/sec: 104469.72
# Step 200/300 | Train Loss: 0.0068 | Train Acc: 1.0000 | Val Loss: 0.5985 | Val Acc: 0.7400 | In-context Acc: 0.7972 | Batch time: 1.13ms | Samples/sec: 103705.11
#
# Training completed!
# Total training time: 0.29 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7400
# Final in-context accuracy: 0.7972
# Average samples/second: 105002.33
# Average batch time: 0.92ms
# Saving checkpoint at checkpoints/checkpoint_d100_B100_R6_20251124_145658_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 200
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 0.6735 | Val Acc: 0.7700 | In-context Acc: 0.8027 | Batch time: 1.93ms | Samples/sec: 49548.78
# Step 100/300 | Train Loss: 0.0045 | Train Acc: 1.0000 | Val Loss: 0.6103 | Val Acc: 0.7800 | In-context Acc: 0.8035 | Batch time: 1.48ms | Samples/sec: 63339.50
# Step 200/300 | Train Loss: 0.0022 | Train Acc: 1.0000 | Val Loss: 0.6022 | Val Acc: 0.7800 | In-context Acc: 0.8035 | Batch time: 1.33ms | Samples/sec: 63185.27
#
# Training completed!
# Total training time: 0.48 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7800
# Final in-context accuracy: 0.8035
# Average samples/second: 62466.95
# Average batch time: 1.56ms
# Saving checkpoint at checkpoints/checkpoint_d200_B100_R8_20251124_145659_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 500
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4500 | Val Loss: 0.6580 | Val Acc: 0.7800 | In-context Acc: 0.8023 | Batch time: 3.69ms | Samples/sec: 26414.16
# Step 100/300 | Train Loss: 0.0008 | Train Acc: 1.0000 | Val Loss: 0.6464 | Val Acc: 0.7800 | In-context Acc: 0.8020 | Batch time: 3.67ms | Samples/sec: 28486.65
# Step 200/300 | Train Loss: 0.0004 | Train Acc: 1.0000 | Val Loss: 0.6429 | Val Acc: 0.7800 | In-context Acc: 0.8018 | Batch time: 3.41ms | Samples/sec: 28251.17
#
# Training completed!
# Total training time: 1.06 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7800
# Final in-context accuracy: 0.8018
# Average samples/second: 28181.21
# Average batch time: 3.49ms
# Saving checkpoint at checkpoints/checkpoint_d500_B100_R12_20251124_145659_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 800
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5000 | Val Loss: 0.6466 | Val Acc: 0.8100 | In-context Acc: 0.7910 | Batch time: 4.16ms | Samples/sec: 23463.33
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6465 | Val Acc: 0.8100 | In-context Acc: 0.7910 | Batch time: 3.73ms | Samples/sec: 22410.19
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6464 | Val Acc: 0.8100 | In-context Acc: 0.7910 | Batch time: 4.05ms | Samples/sec: 22938.50
#
# Training completed!
# Total training time: 1.29 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8100
# Final in-context accuracy: 0.7910
# Average samples/second: 23230.51
# Average batch time: 4.22ms
# Saving checkpoint at checkpoints/checkpoint_d800_B100_R14_20251124_145700_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5500 | Val Loss: 0.6396 | Val Acc: 0.7500 | In-context Acc: 0.8052 | Batch time: 5.61ms | Samples/sec: 17519.34
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6396 | Val Acc: 0.7500 | In-context Acc: 0.8052 | Batch time: 5.64ms | Samples/sec: 17597.65
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6396 | Val Acc: 0.7500 | In-context Acc: 0.8052 | Batch time: 5.68ms | Samples/sec: 17331.10
#
# Training completed!
# Total training time: 1.72 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7500
# Final in-context accuracy: 0.8052
# Average samples/second: 17475.90
# Average batch time: 5.64ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B100_R15_20251124_145702_step_300.pt

# %%
plt.figure(figsize=(8, 5))

plt.plot(ds, train_accs, marker='o', label="Train Acc")
plt.plot(ds, val_accs, marker='o', label="Val Acc")
plt.plot(ds, ic_accs, marker='o', label="In-context Acc")

plt.xlabel("Dimension d")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Input Dimension: R = d^0.4")
plt.grid(True, alpha=0.4)
plt.legend()
plt.tight_layout()
plt.show()

# %%
ds = [10, 20, 50, 100, 200, 500, 800, 1000]
train_accs = []
val_accs = []
ic_accs = []

for d in ds:
    B, steps, label_flip_p = 100, 300, 0.2
    R = d ** 0.6
    params = (d, B, R, R, steps, label_flip_p)
    _, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results/", use_cuda=False)
    train_accs.append(train_acc)
    val_accs.append(val_acc)
    ic_accs.append(ic_acc)
# Out:
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 10
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4900 | Val Loss: 0.6721 | Val Acc: 0.8300 | In-context Acc: 0.7980 | Batch time: 0.48ms | Samples/sec: 152631.15
# Step 100/300 | Train Loss: 0.0493 | Train Acc: 1.0000 | Val Loss: 0.5292 | Val Acc: 0.8300 | In-context Acc: 0.7980 | Batch time: 0.37ms | Samples/sec: 244683.08
# Step 200/300 | Train Loss: 0.0260 | Train Acc: 1.0000 | Val Loss: 0.5570 | Val Acc: 0.8300 | In-context Acc: 0.7980 | Batch time: 0.36ms | Samples/sec: 245475.20
#
# Training completed!
# Total training time: 0.12 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8300
# Final in-context accuracy: 0.7980
# Average samples/second: 246363.88
# Average batch time: 0.37ms
# Saving checkpoint at checkpoints/checkpoint_d10_B100_R3_20251124_145704_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 20
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 0.6325 | Val Acc: 0.8400 | In-context Acc: 0.7940 | Batch time: 0.46ms | Samples/sec: 182838.01
# Step 100/300 | Train Loss: 0.0137 | Train Acc: 1.0000 | Val Loss: 0.4852 | Val Acc: 0.8400 | In-context Acc: 0.7940 | Batch time: 0.38ms | Samples/sec: 238968.76
# Step 200/300 | Train Loss: 0.0069 | Train Acc: 1.0000 | Val Loss: 0.5127 | Val Acc: 0.8400 | In-context Acc: 0.7940 | Batch time: 0.38ms | Samples/sec: 239052.67
#
# Training completed!
# Total training time: 0.13 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8400
# Final in-context accuracy: 0.7940
# Average samples/second: 239944.62
# Average batch time: 0.39ms
# Saving checkpoint at checkpoints/checkpoint_d20_B100_R6_20251124_145704_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 50
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4400 | Val Loss: 0.5734 | Val Acc: 0.7500 | In-context Acc: 0.8045 | Batch time: 0.94ms | Samples/sec: 97451.30
# Step 100/300 | Train Loss: 0.0024 | Train Acc: 1.0000 | Val Loss: 0.6406 | Val Acc: 0.7500 | In-context Acc: 0.8045 | Batch time: 0.41ms | Samples/sec: 221991.79
# Step 200/300 | Train Loss: 0.0012 | Train Acc: 1.0000 | Val Loss: 0.6756 | Val Acc: 0.7500 | In-context Acc: 0.8045 | Batch time: 0.41ms | Samples/sec: 223112.49
#
# Training completed!
# Total training time: 0.13 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7500
# Final in-context accuracy: 0.8045
# Average samples/second: 224399.53
# Average batch time: 0.41ms
# Saving checkpoint at checkpoints/checkpoint_d50_B100_R10_20251124_145704_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 100
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4200 | Val Loss: 0.6300 | Val Acc: 0.7500 | In-context Acc: 0.7960 | Batch time: 1.49ms | Samples/sec: 63453.92
# Step 100/300 | Train Loss: 0.0003 | Train Acc: 1.0000 | Val Loss: 0.6501 | Val Acc: 0.7500 | In-context Acc: 0.7960 | Batch time: 0.90ms | Samples/sec: 118463.95
# Step 200/300 | Train Loss: 0.0002 | Train Acc: 1.0000 | Val Loss: 0.6629 | Val Acc: 0.7500 | In-context Acc: 0.7960 | Batch time: 0.99ms | Samples/sec: 118898.41
#
# Training completed!
# Total training time: 0.25 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7500
# Final in-context accuracy: 0.7960
# Average samples/second: 118270.90
# Average batch time: 0.81ms
# Saving checkpoint at checkpoints/checkpoint_d100_B100_R15_20251124_145704_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 200
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 1.0002 | Val Acc: 0.8000 | In-context Acc: 0.8035 | Batch time: 1.66ms | Samples/sec: 57574.52
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 1.0002 | Val Acc: 0.8000 | In-context Acc: 0.8035 | Batch time: 1.06ms | Samples/sec: 75940.45
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 1.0002 | Val Acc: 0.8000 | In-context Acc: 0.8035 | Batch time: 0.89ms | Samples/sec: 78047.07
#
# Training completed!
# Total training time: 0.38 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8000
# Final in-context accuracy: 0.8035
# Average samples/second: 78359.44
# Average batch time: 1.24ms
# Saving checkpoint at checkpoints/checkpoint_d200_B100_R24_20251124_145705_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 500
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4500 | Val Loss: 3.7500 | Val Acc: 0.8100 | In-context Acc: 0.8012 | Batch time: 3.76ms | Samples/sec: 25959.67
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 3.7500 | Val Acc: 0.8100 | In-context Acc: 0.8012 | Batch time: 2.80ms | Samples/sec: 27769.35
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 3.7500 | Val Acc: 0.8100 | In-context Acc: 0.8012 | Batch time: 3.43ms | Samples/sec: 28039.33
#
# Training completed!
# Total training time: 1.07 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8100
# Final in-context accuracy: 0.8012
# Average samples/second: 27960.55
# Average batch time: 3.52ms
# Saving checkpoint at checkpoints/checkpoint_d500_B100_R41_20251124_145705_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 800
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5000 | Val Loss: 6.2021 | Val Acc: 0.8300 | In-context Acc: 0.7897 | Batch time: 4.30ms | Samples/sec: 22748.15
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 6.2021 | Val Acc: 0.8300 | In-context Acc: 0.7897 | Batch time: 3.67ms | Samples/sec: 24533.56
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 6.2021 | Val Acc: 0.8300 | In-context Acc: 0.7897 | Batch time: 3.63ms | Samples/sec: 24839.54
#
# Training completed!
# Total training time: 1.21 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8300
# Final in-context accuracy: 0.7897
# Average samples/second: 24747.25
# Average batch time: 3.96ms
# Saving checkpoint at checkpoints/checkpoint_d800_B100_R55_20251124_145706_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5500 | Val Loss: 10.5436 | Val Acc: 0.7700 | In-context Acc: 0.8073 | Batch time: 5.55ms | Samples/sec: 17686.29
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 10.5436 | Val Acc: 0.7700 | In-context Acc: 0.8073 | Batch time: 5.78ms | Samples/sec: 17630.74
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 10.5436 | Val Acc: 0.7700 | In-context Acc: 0.8073 | Batch time: 5.12ms | Samples/sec: 17629.47
#
# Training completed!
# Total training time: 1.70 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7700
# Final in-context accuracy: 0.8073
# Average samples/second: 17672.67
# Average batch time: 5.57ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B100_R63_20251124_145708_step_300.pt

# %%
plt.figure(figsize=(8, 5))

plt.plot(ds, train_accs, marker='o', label="Train Acc")
plt.plot(ds, val_accs, marker='o', label="Val Acc")
plt.plot(ds, ic_accs, marker='o', label="In-context Acc")

plt.xlabel("Dimension d")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Input Dimension: R = d^0.6")
plt.grid(True, alpha=0.4)
plt.legend()
plt.tight_layout()
plt.show()

# %%
ds = [10, 20, 50, 100, 200, 500, 800, 1000]
train_accs = []
val_accs = []
ic_accs = []

for d in ds:
    B, steps, label_flip_p = 100, 300, 0.2
    R = d ** 0.8
    params = (d, B, R, R, steps, label_flip_p)
    _, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results/", use_cuda=False)
    train_accs.append(train_acc)
    val_accs.append(val_acc)
    ic_accs.append(ic_acc)
# Out:
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 10
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4900 | Val Loss: 0.5803 | Val Acc: 0.8300 | In-context Acc: 0.7980 | Batch time: 1.00ms | Samples/sec: 84189.16
# Step 100/300 | Train Loss: 0.0071 | Train Acc: 1.0000 | Val Loss: 0.6130 | Val Acc: 0.8300 | In-context Acc: 0.7980 | Batch time: 0.37ms | Samples/sec: 241921.96
# Step 200/300 | Train Loss: 0.0036 | Train Acc: 1.0000 | Val Loss: 0.6675 | Val Acc: 0.8300 | In-context Acc: 0.7980 | Batch time: 0.38ms | Samples/sec: 242303.17
#
# Training completed!
# Total training time: 0.12 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8300
# Final in-context accuracy: 0.7980
# Average samples/second: 243952.28
# Average batch time: 0.38ms
# Saving checkpoint at checkpoints/checkpoint_d10_B100_R6_20251124_145710_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 20
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 0.4778 | Val Acc: 0.8400 | In-context Acc: 0.7940 | Batch time: 0.96ms | Samples/sec: 95520.47
# Step 100/300 | Train Loss: 0.0011 | Train Acc: 1.0000 | Val Loss: 0.6159 | Val Acc: 0.8400 | In-context Acc: 0.7940 | Batch time: 0.39ms | Samples/sec: 231540.78
# Step 200/300 | Train Loss: 0.0006 | Train Acc: 1.0000 | Val Loss: 0.6623 | Val Acc: 0.8400 | In-context Acc: 0.7940 | Batch time: 0.39ms | Samples/sec: 236414.78
#
# Training completed!
# Total training time: 0.13 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8400
# Final in-context accuracy: 0.7940
# Average samples/second: 237641.21
# Average batch time: 0.39ms
# Saving checkpoint at checkpoints/checkpoint_d20_B100_R10_20251124_145710_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 50
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4400 | Val Loss: 4.0487 | Val Acc: 0.7500 | In-context Acc: 0.8045 | Batch time: 0.48ms | Samples/sec: 176379.48
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 4.0487 | Val Acc: 0.7500 | In-context Acc: 0.8045 | Batch time: 0.41ms | Samples/sec: 223155.34
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 4.0487 | Val Acc: 0.7500 | In-context Acc: 0.8045 | Batch time: 0.41ms | Samples/sec: 223984.46
#
# Training completed!
# Total training time: 0.13 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7500
# Final in-context accuracy: 0.8045
# Average samples/second: 224870.74
# Average batch time: 0.41ms
# Saving checkpoint at checkpoints/checkpoint_d50_B100_R22_20251124_145710_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 100
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4200 | Val Loss: 18.5553 | Val Acc: 0.7500 | In-context Acc: 0.7960 | Batch time: 1.61ms | Samples/sec: 59308.60
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 18.5553 | Val Acc: 0.7500 | In-context Acc: 0.7960 | Batch time: 0.76ms | Samples/sec: 106545.72
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 18.5553 | Val Acc: 0.7500 | In-context Acc: 0.7960 | Batch time: 0.85ms | Samples/sec: 105426.69
#
# Training completed!
# Total training time: 0.28 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7500
# Final in-context accuracy: 0.7960
# Average samples/second: 106856.71
# Average batch time: 0.90ms
# Saving checkpoint at checkpoints/checkpoint_d100_B100_R39_20251124_145710_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 200
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 68.6743 | Val Acc: 0.8000 | In-context Acc: 0.8035 | Batch time: 2.40ms | Samples/sec: 40225.41
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 68.6743 | Val Acc: 0.8000 | In-context Acc: 0.8035 | Batch time: 1.38ms | Samples/sec: 60627.55
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 68.6743 | Val Acc: 0.8000 | In-context Acc: 0.8035 | Batch time: 1.76ms | Samples/sec: 60367.80
#
# Training completed!
# Total training time: 0.49 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8000
# Final in-context accuracy: 0.8035
# Average samples/second: 61465.69
# Average batch time: 1.59ms
# Saving checkpoint at checkpoints/checkpoint_d200_B100_R69_20251124_145710_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 500
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4500 | Val Loss: 538.7279 | Val Acc: 0.8100 | In-context Acc: 0.8012 | Batch time: 3.37ms | Samples/sec: 28926.23
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 538.7279 | Val Acc: 0.8100 | In-context Acc: 0.8012 | Batch time: 3.18ms | Samples/sec: 27549.05
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 538.7279 | Val Acc: 0.8100 | In-context Acc: 0.8012 | Batch time: 3.74ms | Samples/sec: 27271.87
#
# Training completed!
# Total training time: 1.11 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8100
# Final in-context accuracy: 0.8012
# Average samples/second: 27127.35
# Average batch time: 3.63ms
# Saving checkpoint at checkpoints/checkpoint_d500_B100_R144_20251124_145711_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 800
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5000 | Val Loss: 1295.7286 | Val Acc: 0.8300 | In-context Acc: 0.7897 | Batch time: 4.99ms | Samples/sec: 19664.79
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 1295.7286 | Val Acc: 0.8300 | In-context Acc: 0.7897 | Batch time: 4.14ms | Samples/sec: 23828.83
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 1295.7286 | Val Acc: 0.8300 | In-context Acc: 0.7897 | Batch time: 3.60ms | Samples/sec: 24165.07
#
# Training completed!
# Total training time: 1.24 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8300
# Final in-context accuracy: 0.7897
# Average samples/second: 24195.85
# Average batch time: 4.05ms
# Saving checkpoint at checkpoints/checkpoint_d800_B100_R210_20251124_145712_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5500 | Val Loss: 2660.9155 | Val Acc: 0.7700 | In-context Acc: 0.8073 | Batch time: 5.66ms | Samples/sec: 17372.75
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 2660.9155 | Val Acc: 0.7700 | In-context Acc: 0.8073 | Batch time: 5.56ms | Samples/sec: 17846.42
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 2660.9155 | Val Acc: 0.7700 | In-context Acc: 0.8073 | Batch time: 5.48ms | Samples/sec: 17693.96
#
# Training completed!
# Total training time: 1.69 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7700
# Final in-context accuracy: 0.8073
# Average samples/second: 17737.16
# Average batch time: 5.55ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B100_R251_20251124_145714_step_300.pt

# %%
plt.figure(figsize=(8, 5))

plt.plot(ds, train_accs, marker='o', label="Train Acc")
plt.plot(ds, val_accs, marker='o', label="Val Acc")
plt.plot(ds, ic_accs, marker='o', label="In-context Acc")

plt.xlabel("Dimension d")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Input Dimension: R = d^0.8")
plt.grid(True, alpha=0.4)
plt.legend()
plt.tight_layout()
plt.show()

# %%
Bs = [1, 5, 10, 50, 100, 500, 1000]
train_accs = []
val_accs = []
ic_accs = []

for B in Bs:
    d, steps, label_flip_p = 1000, 300, 0.2
    R = d ** 0.1
    params = (d, B, R, R, steps, label_flip_p)
    _, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results/", use_cuda=False)
    train_accs.append(train_acc)
    val_accs.append(val_acc)
    ic_accs.append(ic_acc)
# Out:
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 1
# Validation tasks: 50
# Batch size: 1
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 1.0000 | Val Loss: 0.6933 | Val Acc: 0.0000 | In-context Acc: 0.5500 | Batch time: 1.03ms | Samples/sec: 824.35
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6933 | Val Acc: 0.0000 | In-context Acc: 0.5500 | Batch time: 1.42ms | Samples/sec: 968.60
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6933 | Val Acc: 0.0000 | In-context Acc: 0.5500 | Batch time: 1.23ms | Samples/sec: 1091.71
#
# Training completed!
# Total training time: 0.27 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.0000
# Final in-context accuracy: 0.5500
# Average samples/second: 1119.47
# Average batch time: 0.86ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B1_R1_20251124_145715_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 5
# Validation tasks: 50
# Batch size: 5
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4000 | Val Loss: 0.7014 | Val Acc: 0.4000 | In-context Acc: 0.5650 | Batch time: 1.08ms | Samples/sec: 4283.40
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.7014 | Val Acc: 0.4000 | In-context Acc: 0.5650 | Batch time: 1.05ms | Samples/sec: 4957.62
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.7014 | Val Acc: 0.4000 | In-context Acc: 0.5650 | Batch time: 1.18ms | Samples/sec: 4891.41
#
# Training completed!
# Total training time: 0.31 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.4000
# Final in-context accuracy: 0.5650
# Average samples/second: 4899.22
# Average batch time: 0.98ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B5_R1_20251124_145716_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 10
# Validation tasks: 50
# Batch size: 10
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.6000 | Val Loss: 0.6888 | Val Acc: 0.6000 | In-context Acc: 0.4850 | Batch time: 1.84ms | Samples/sec: 5152.07
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6888 | Val Acc: 0.6000 | In-context Acc: 0.4850 | Batch time: 1.38ms | Samples/sec: 7029.23
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6888 | Val Acc: 0.6000 | In-context Acc: 0.4850 | Batch time: 1.15ms | Samples/sec: 7154.28
#
# Training completed!
# Total training time: 0.42 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.6000
# Final in-context accuracy: 0.4850
# Average samples/second: 7205.03
# Average batch time: 1.35ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B10_R1_20251124_145716_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 50
# Validation tasks: 50
# Batch size: 50
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5600 | Val Loss: 0.6952 | Val Acc: 0.3800 | In-context Acc: 0.5075 | Batch time: 3.96ms | Samples/sec: 12322.42
# Step 100/300 | Train Loss: 0.0017 | Train Acc: 1.0000 | Val Loss: 0.6979 | Val Acc: 0.4000 | In-context Acc: 0.5065 | Batch time: 4.02ms | Samples/sec: 11851.54
# Step 200/300 | Train Loss: 0.0009 | Train Acc: 1.0000 | Val Loss: 0.6984 | Val Acc: 0.4000 | In-context Acc: 0.5070 | Batch time: 4.39ms | Samples/sec: 12070.49
#
# Training completed!
# Total training time: 1.24 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.4000
# Final in-context accuracy: 0.5080
# Average samples/second: 12125.25
# Average batch time: 4.05ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B50_R1_20251124_145717_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 0.6931 | Val Acc: 0.4900 | In-context Acc: 0.5153 | Batch time: 6.77ms | Samples/sec: 14543.36
# Step 100/300 | Train Loss: 0.0034 | Train Acc: 1.0000 | Val Loss: 0.6930 | Val Acc: 0.4800 | In-context Acc: 0.5155 | Batch time: 5.78ms | Samples/sec: 17695.08
# Step 200/300 | Train Loss: 0.0017 | Train Acc: 1.0000 | Val Loss: 0.6931 | Val Acc: 0.4800 | In-context Acc: 0.5155 | Batch time: 5.10ms | Samples/sec: 17711.90
#
# Training completed!
# Total training time: 1.68 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.4800
# Final in-context accuracy: 0.5153
# Average samples/second: 17851.97
# Average batch time: 5.52ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B100_R1_20251124_145718_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 500
# Validation tasks: 50
# Batch size: 500
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5000 | Val Loss: 0.6932 | Val Acc: 0.4820 | In-context Acc: 0.5282 | Batch time: 29.53ms | Samples/sec: 16818.12
# Step 100/300 | Train Loss: 0.0176 | Train Acc: 1.0000 | Val Loss: 0.6943 | Val Acc: 0.4760 | In-context Acc: 0.5290 | Batch time: 27.24ms | Samples/sec: 18298.93
# Step 200/300 | Train Loss: 0.0087 | Train Acc: 1.0000 | Val Loss: 0.6947 | Val Acc: 0.4760 | In-context Acc: 0.5289 | Batch time: 27.43ms | Samples/sec: 18313.82
#
# Training completed!
# Total training time: 8.18 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.4760
# Final in-context accuracy: 0.5288
# Average samples/second: 18334.48
# Average batch time: 27.18ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B500_R1_20251124_145720_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 1000
# Validation tasks: 50
# Batch size: 1000
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5050 | Val Loss: 0.6931 | Val Acc: 0.5090 | In-context Acc: 0.5522 | Batch time: 64.13ms | Samples/sec: 15542.46
# Step 100/300 | Train Loss: 0.0363 | Train Acc: 1.0000 | Val Loss: 0.6942 | Val Acc: 0.5070 | In-context Acc: 0.5525 | Batch time: 64.32ms | Samples/sec: 15336.72
# Step 200/300 | Train Loss: 0.0179 | Train Acc: 1.0000 | Val Loss: 0.6947 | Val Acc: 0.5080 | In-context Acc: 0.5525 | Batch time: 64.07ms | Samples/sec: 15371.07
#
# Training completed!
# Total training time: 19.40 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.5080
# Final in-context accuracy: 0.5525
# Average samples/second: 15464.84
# Average batch time: 64.57ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B1000_R1_20251124_145728_step_300.pt

# %%
plt.figure(figsize=(8, 5))

plt.plot(Bs, train_accs, marker='o', label="Train Acc")
plt.plot(Bs, val_accs, marker='o', label="Val Acc")
plt.plot(Bs, ic_accs, marker='o', label="In-context Acc")

plt.xlabel("Dimension d")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Input Dimension: R = d^0.1")
plt.grid(True, alpha=0.4)
plt.legend()
plt.tight_layout()
plt.show()

# %%
Bs = [1, 5, 10, 50, 100, 500, 1000]
train_accs = []
val_accs = []
ic_accs = []

for B in Bs:
    d, steps, label_flip_p = 1000, 300, 0.2
    R = d ** 0.3
    params = (d, B, R, R, steps, label_flip_p)
    _, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results/", use_cuda=False)
    train_accs.append(train_acc)
    val_accs.append(val_acc)
    ic_accs.append(ic_acc)
# Out:
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 1
# Validation tasks: 50
# Batch size: 1
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 1.0000 | Val Loss: 0.5400 | Val Acc: 1.0000 | In-context Acc: 0.5000 | Batch time: 1.06ms | Samples/sec: 798.00
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5400 | Val Acc: 1.0000 | In-context Acc: 0.5000 | Batch time: 0.94ms | Samples/sec: 1077.25
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5400 | Val Acc: 1.0000 | In-context Acc: 0.5000 | Batch time: 0.95ms | Samples/sec: 1092.24
#
# Training completed!
# Total training time: 0.27 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 1.0000
# Final in-context accuracy: 0.5000
# Average samples/second: 1109.92
# Average batch time: 0.87ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B1_R7_20251124_145749_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 5
# Validation tasks: 50
# Batch size: 5
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4000 | Val Loss: 0.7163 | Val Acc: 0.4000 | In-context Acc: 0.5100 | Batch time: 1.40ms | Samples/sec: 3371.63
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.7163 | Val Acc: 0.4000 | In-context Acc: 0.5100 | Batch time: 1.17ms | Samples/sec: 4390.24
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.7163 | Val Acc: 0.4000 | In-context Acc: 0.5100 | Batch time: 1.11ms | Samples/sec: 4585.61
#
# Training completed!
# Total training time: 0.32 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.4000
# Final in-context accuracy: 0.5100
# Average samples/second: 4664.89
# Average batch time: 1.04ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B5_R7_20251124_145749_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 10
# Validation tasks: 50
# Batch size: 10
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.6000 | Val Loss: 0.6842 | Val Acc: 0.5000 | In-context Acc: 0.5400 | Batch time: 1.47ms | Samples/sec: 6418.22
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6842 | Val Acc: 0.5000 | In-context Acc: 0.5400 | Batch time: 1.48ms | Samples/sec: 6097.56
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6842 | Val Acc: 0.5000 | In-context Acc: 0.5400 | Batch time: 1.61ms | Samples/sec: 6253.58
#
# Training completed!
# Total training time: 0.48 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.5000
# Final in-context accuracy: 0.5400
# Average samples/second: 6303.41
# Average batch time: 1.55ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B10_R7_20251124_145749_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 50
# Validation tasks: 50
# Batch size: 50
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5600 | Val Loss: 0.6935 | Val Acc: 0.4800 | In-context Acc: 0.6170 | Batch time: 4.32ms | Samples/sec: 11315.16
# Step 100/300 | Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.6935 | Val Acc: 0.4800 | In-context Acc: 0.6160 | Batch time: 5.08ms | Samples/sec: 11610.69
# Step 200/300 | Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.6935 | Val Acc: 0.4800 | In-context Acc: 0.6145 | Batch time: 3.53ms | Samples/sec: 11568.40
#
# Training completed!
# Total training time: 1.29 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.4800
# Final in-context accuracy: 0.6145
# Average samples/second: 11644.45
# Average batch time: 4.22ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B50_R7_20251124_145750_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 0.6898 | Val Acc: 0.5800 | In-context Acc: 0.6762 | Batch time: 5.82ms | Samples/sec: 16903.66
# Step 100/300 | Train Loss: 0.0009 | Train Acc: 1.0000 | Val Loss: 0.6882 | Val Acc: 0.5600 | In-context Acc: 0.6750 | Batch time: 5.73ms | Samples/sec: 17517.21
# Step 200/300 | Train Loss: 0.0005 | Train Acc: 1.0000 | Val Loss: 0.6878 | Val Acc: 0.5600 | In-context Acc: 0.6755 | Batch time: 6.40ms | Samples/sec: 17454.59
#
# Training completed!
# Total training time: 1.73 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.5600
# Final in-context accuracy: 0.6755
# Average samples/second: 17359.82
# Average batch time: 5.67ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B100_R7_20251124_145751_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 500
# Validation tasks: 50
# Batch size: 500
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5000 | Val Loss: 0.6893 | Val Acc: 0.6800 | In-context Acc: 0.7999 | Batch time: 26.67ms | Samples/sec: 18609.43
# Step 100/300 | Train Loss: 0.0052 | Train Acc: 1.0000 | Val Loss: 0.6733 | Val Acc: 0.6880 | In-context Acc: 0.7997 | Batch time: 27.31ms | Samples/sec: 18502.42
# Step 200/300 | Train Loss: 0.0026 | Train Acc: 1.0000 | Val Loss: 0.6709 | Val Acc: 0.6880 | In-context Acc: 0.7997 | Batch time: 27.21ms | Samples/sec: 18504.65
#
# Training completed!
# Total training time: 8.11 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.6880
# Final in-context accuracy: 0.8000
# Average samples/second: 18488.39
# Average batch time: 26.95ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B500_R7_20251124_145753_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 1000
# Validation tasks: 50
# Batch size: 1000
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5050 | Val Loss: 0.6898 | Val Acc: 0.7150 | In-context Acc: 0.8502 | Batch time: 68.87ms | Samples/sec: 14494.66
# Step 100/300 | Train Loss: 0.0104 | Train Acc: 1.0000 | Val Loss: 0.6642 | Val Acc: 0.7160 | In-context Acc: 0.8498 | Batch time: 65.44ms | Samples/sec: 15302.36
# Step 200/300 | Train Loss: 0.0052 | Train Acc: 1.0000 | Val Loss: 0.6603 | Val Acc: 0.7160 | In-context Acc: 0.8498 | Batch time: 65.46ms | Samples/sec: 15326.18
#
# Training completed!
# Total training time: 19.57 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7150
# Final in-context accuracy: 0.8497
# Average samples/second: 15332.79
# Average batch time: 65.12ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B1000_R7_20251124_145802_step_300.pt
