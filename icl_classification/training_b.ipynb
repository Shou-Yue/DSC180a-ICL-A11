# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
from classification_icl import run_single_experiment
# Out:
# /Users/sebastianleng/miniforge3/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /Users/sebastianleng/miniforge3/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %%
Bs = [1, 5, 10, 50, 100, 500, 1000]
train_accs = []
val_accs = []
ic_accs = []

for B in Bs:
    d, steps, label_flip_p = 1000, 300, 0.2
    R = d ** 0.1
    params = (d, B, R, R, steps, label_flip_p)
    _, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results/", use_cuda=False)
    train_accs.append(train_acc)
    val_accs.append(val_acc)
    ic_accs.append(ic_acc)
# Out:
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 1
# Validation tasks: 50
# Batch size: 1
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.0000 | Val Loss: 0.6804 | Val Acc: 1.0000 | In-context Acc: 0.6250 | Batch time: 9.47ms | Samples/sec: 101.66
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6804 | Val Acc: 1.0000 | In-context Acc: 0.6250 | Batch time: 0.73ms | Samples/sec: 1232.95
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6804 | Val Acc: 1.0000 | In-context Acc: 0.6250 | Batch time: 0.62ms | Samples/sec: 1313.47
#
# Training completed!
# Total training time: 0.23 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 1.0000
# Final in-context accuracy: 0.6250
# Average samples/second: 1331.93
# Average batch time: 0.72ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B1_R1_20251124_144123_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 5
# Validation tasks: 50
# Batch size: 5
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4000 | Val Loss: 0.7014 | Val Acc: 0.4000 | In-context Acc: 0.5650 | Batch time: 0.98ms | Samples/sec: 4659.30
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.7014 | Val Acc: 0.4000 | In-context Acc: 0.5650 | Batch time: 0.99ms | Samples/sec: 5921.31
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.7014 | Val Acc: 0.4000 | In-context Acc: 0.5650 | Batch time: 0.86ms | Samples/sec: 5908.42
#
# Training completed!
# Total training time: 0.25 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.4000
# Final in-context accuracy: 0.5650
# Average samples/second: 5992.78
# Average batch time: 0.80ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B5_R1_20251124_144124_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 10
# Validation tasks: 50
# Batch size: 10
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.6000 | Val Loss: 0.6888 | Val Acc: 0.6000 | In-context Acc: 0.4850 | Batch time: 1.38ms | Samples/sec: 6779.22
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6888 | Val Acc: 0.6000 | In-context Acc: 0.4850 | Batch time: 0.90ms | Samples/sec: 8768.05
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6888 | Val Acc: 0.6000 | In-context Acc: 0.4850 | Batch time: 1.02ms | Samples/sec: 9024.98
#
# Training completed!
# Total training time: 0.33 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.6000
# Final in-context accuracy: 0.4850
# Average samples/second: 9082.66
# Average batch time: 1.06ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B10_R1_20251124_144125_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 50
# Validation tasks: 50
# Batch size: 50
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5600 | Val Loss: 0.6952 | Val Acc: 0.3800 | In-context Acc: 0.5075 | Batch time: 5.17ms | Samples/sec: 9507.44
# Step 100/300 | Train Loss: 0.0017 | Train Acc: 1.0000 | Val Loss: 0.6979 | Val Acc: 0.4000 | In-context Acc: 0.5065 | Batch time: 3.85ms | Samples/sec: 12050.29
# Step 200/300 | Train Loss: 0.0009 | Train Acc: 1.0000 | Val Loss: 0.6984 | Val Acc: 0.4000 | In-context Acc: 0.5070 | Batch time: 3.47ms | Samples/sec: 12404.32
#
# Training completed!
# Total training time: 1.23 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.4000
# Final in-context accuracy: 0.5080
# Average samples/second: 12179.26
# Average batch time: 4.03ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B50_R1_20251124_144125_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 0.6931 | Val Acc: 0.4900 | In-context Acc: 0.5153 | Batch time: 8.03ms | Samples/sec: 12291.00
# Step 100/300 | Train Loss: 0.0034 | Train Acc: 1.0000 | Val Loss: 0.6930 | Val Acc: 0.4800 | In-context Acc: 0.5155 | Batch time: 5.44ms | Samples/sec: 15633.20
# Step 200/300 | Train Loss: 0.0017 | Train Acc: 1.0000 | Val Loss: 0.6931 | Val Acc: 0.4800 | In-context Acc: 0.5155 | Batch time: 6.07ms | Samples/sec: 15945.04
#
# Training completed!
# Total training time: 1.87 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.4800
# Final in-context accuracy: 0.5153
# Average samples/second: 16022.48
# Average batch time: 6.14ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B100_R1_20251124_144126_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 500
# Validation tasks: 50
# Batch size: 500
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5000 | Val Loss: 0.6932 | Val Acc: 0.4820 | In-context Acc: 0.5282 | Batch time: 32.43ms | Samples/sec: 15318.08
# Step 100/300 | Train Loss: 0.0176 | Train Acc: 1.0000 | Val Loss: 0.6943 | Val Acc: 0.4760 | In-context Acc: 0.5290 | Batch time: 27.19ms | Samples/sec: 17777.44
# Step 200/300 | Train Loss: 0.0087 | Train Acc: 1.0000 | Val Loss: 0.6947 | Val Acc: 0.4760 | In-context Acc: 0.5289 | Batch time: 27.39ms | Samples/sec: 17768.93
#
# Training completed!
# Total training time: 8.44 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.4760
# Final in-context accuracy: 0.5288
# Average samples/second: 17778.73
# Average batch time: 28.02ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B500_R1_20251124_144128_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 1000
# Validation tasks: 50
# Batch size: 1000
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5050 | Val Loss: 0.6931 | Val Acc: 0.5090 | In-context Acc: 0.5522 | Batch time: 67.23ms | Samples/sec: 14826.68
# Step 100/300 | Train Loss: 0.0363 | Train Acc: 1.0000 | Val Loss: 0.6942 | Val Acc: 0.5070 | In-context Acc: 0.5525 | Batch time: 63.54ms | Samples/sec: 15284.48
# Step 200/300 | Train Loss: 0.0179 | Train Acc: 1.0000 | Val Loss: 0.6947 | Val Acc: 0.5080 | In-context Acc: 0.5525 | Batch time: 65.72ms | Samples/sec: 15412.02
#
# Training completed!
# Total training time: 19.47 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.5080
# Final in-context accuracy: 0.5525
# Average samples/second: 15406.08
# Average batch time: 64.81ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B1000_R1_20251124_144137_step_300.pt

# %%
plt.figure(figsize=(8, 5))

plt.plot(Bs, train_accs, marker='o', label="Train Acc")
plt.plot(Bs, val_accs, marker='o', label="Val Acc")
plt.plot(Bs, ic_accs, marker='o', label="In-context Acc")

plt.xlabel("Number of Tasks B")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Number of Tasks: R = d^0.1")
plt.grid(True, alpha=0.4)
plt.legend()
plt.tight_layout()
plt.show()

# %%
Bs = [1, 5, 10, 50, 100, 500, 1000]
train_accs = []
val_accs = []
ic_accs = []

for B in Bs:
    d, steps, label_flip_p = 1000, 300, 0.2
    R = d ** 0.3
    params = (d, B, R, R, steps, label_flip_p)
    _, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results/", use_cuda=False)
    train_accs.append(train_acc)
    val_accs.append(val_acc)
    ic_accs.append(ic_acc)
# Out:
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 1
# Validation tasks: 50
# Batch size: 1
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 1.0000 | Val Loss: 0.5400 | Val Acc: 1.0000 | In-context Acc: 0.5000 | Batch time: 1.49ms | Samples/sec: 549.42
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5400 | Val Acc: 1.0000 | In-context Acc: 0.5000 | Batch time: 0.74ms | Samples/sec: 1018.74
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5400 | Val Acc: 1.0000 | In-context Acc: 0.5000 | Batch time: 0.86ms | Samples/sec: 1121.83
#
# Training completed!
# Total training time: 0.26 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 1.0000
# Final in-context accuracy: 0.5000
# Average samples/second: 1135.14
# Average batch time: 0.84ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B1_R7_20251124_144250_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 5
# Validation tasks: 50
# Batch size: 5
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4000 | Val Loss: 0.7163 | Val Acc: 0.4000 | In-context Acc: 0.5100 | Batch time: 1.09ms | Samples/sec: 4269.45
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.7163 | Val Acc: 0.4000 | In-context Acc: 0.5100 | Batch time: 0.79ms | Samples/sec: 5168.51
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.7163 | Val Acc: 0.4000 | In-context Acc: 0.5100 | Batch time: 1.23ms | Samples/sec: 5259.11
#
# Training completed!
# Total training time: 0.29 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.4000
# Final in-context accuracy: 0.5100
# Average samples/second: 5238.40
# Average batch time: 0.92ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B5_R7_20251124_144251_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 10
# Validation tasks: 50
# Batch size: 10
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.6000 | Val Loss: 0.6842 | Val Acc: 0.5000 | In-context Acc: 0.5400 | Batch time: 1.58ms | Samples/sec: 6009.89
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6842 | Val Acc: 0.5000 | In-context Acc: 0.5400 | Batch time: 1.07ms | Samples/sec: 7515.27
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6842 | Val Acc: 0.5000 | In-context Acc: 0.5400 | Batch time: 1.09ms | Samples/sec: 7674.92
#
# Training completed!
# Total training time: 0.39 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.5000
# Final in-context accuracy: 0.5400
# Average samples/second: 7635.04
# Average batch time: 1.27ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B10_R7_20251124_144251_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 50
# Validation tasks: 50
# Batch size: 50
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5600 | Val Loss: 0.6935 | Val Acc: 0.4800 | In-context Acc: 0.6170 | Batch time: 5.09ms | Samples/sec: 9443.23
# Step 100/300 | Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.6935 | Val Acc: 0.4800 | In-context Acc: 0.6160 | Batch time: 3.44ms | Samples/sec: 12083.92
# Step 200/300 | Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.6935 | Val Acc: 0.4800 | In-context Acc: 0.6145 | Batch time: 3.80ms | Samples/sec: 11501.54
#
# Training completed!
# Total training time: 1.32 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.4800
# Final in-context accuracy: 0.6145
# Average samples/second: 11393.16
# Average batch time: 4.31ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B50_R7_20251124_144251_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 0.6898 | Val Acc: 0.5800 | In-context Acc: 0.6762 | Batch time: 6.55ms | Samples/sec: 15022.04
# Step 100/300 | Train Loss: 0.0009 | Train Acc: 1.0000 | Val Loss: 0.6882 | Val Acc: 0.5600 | In-context Acc: 0.6750 | Batch time: 5.34ms | Samples/sec: 15527.23
# Step 200/300 | Train Loss: 0.0005 | Train Acc: 1.0000 | Val Loss: 0.6878 | Val Acc: 0.5600 | In-context Acc: 0.6755 | Batch time: 5.35ms | Samples/sec: 16337.36
#
# Training completed!
# Total training time: 1.84 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.5600
# Final in-context accuracy: 0.6755
# Average samples/second: 16324.74
# Average batch time: 6.03ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B100_R7_20251124_144253_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 500
# Validation tasks: 50
# Batch size: 500
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5000 | Val Loss: 0.6893 | Val Acc: 0.6800 | In-context Acc: 0.7999 | Batch time: 29.96ms | Samples/sec: 16571.46
# Step 100/300 | Train Loss: 0.0052 | Train Acc: 1.0000 | Val Loss: 0.6733 | Val Acc: 0.6880 | In-context Acc: 0.7997 | Batch time: 27.51ms | Samples/sec: 18127.19
# Step 200/300 | Train Loss: 0.0026 | Train Acc: 1.0000 | Val Loss: 0.6709 | Val Acc: 0.6880 | In-context Acc: 0.7997 | Batch time: 26.89ms | Samples/sec: 18001.79
#
# Training completed!
# Total training time: 8.30 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.6880
# Final in-context accuracy: 0.8000
# Average samples/second: 18067.74
# Average batch time: 27.57ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B500_R7_20251124_144255_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 1000
# Validation tasks: 50
# Batch size: 1000
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5050 | Val Loss: 0.6898 | Val Acc: 0.7150 | In-context Acc: 0.8502 | Batch time: 72.53ms | Samples/sec: 13746.09
# Step 100/300 | Train Loss: 0.0104 | Train Acc: 1.0000 | Val Loss: 0.6642 | Val Acc: 0.7160 | In-context Acc: 0.8498 | Batch time: 64.48ms | Samples/sec: 15637.74
# Step 200/300 | Train Loss: 0.0052 | Train Acc: 1.0000 | Val Loss: 0.6603 | Val Acc: 0.7160 | In-context Acc: 0.8498 | Batch time: 63.93ms | Samples/sec: 15558.89
#
# Training completed!
# Total training time: 19.61 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7150
# Final in-context accuracy: 0.8497
# Average samples/second: 15297.98
# Average batch time: 65.26ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B1000_R7_20251124_144303_step_300.pt

# %%
plt.figure(figsize=(8, 5))

plt.plot(Bs, train_accs, marker='o', label="Train Acc")
plt.plot(Bs, val_accs, marker='o', label="Val Acc")
plt.plot(Bs, ic_accs, marker='o', label="In-context Acc")

plt.xlabel("Number of Tasks B")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Number of Tasks: R = d^0.3")
plt.grid(True, alpha=0.4)
plt.legend()
plt.tight_layout()
plt.show()

# %%
Bs = [1, 5, 10, 50, 100, 500, 1000]
train_accs = []
val_accs = []
ic_accs = []

for B in Bs:
    d, steps, label_flip_p = 1000, 300, 0.2
    R = d ** 0.4
    params = (d, B, R, R, steps, label_flip_p)
    _, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results/", use_cuda=False)
    train_accs.append(train_acc)
    val_accs.append(val_acc)
    ic_accs.append(ic_acc)
# Out:
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 1
# Validation tasks: 50
# Batch size: 1
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 1.0000 | Val Loss: 0.3232 | Val Acc: 1.0000 | In-context Acc: 0.5000 | Batch time: 1.46ms | Samples/sec: 547.63
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.3232 | Val Acc: 1.0000 | In-context Acc: 0.5000 | Batch time: 0.73ms | Samples/sec: 1095.76
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.3232 | Val Acc: 1.0000 | In-context Acc: 0.5000 | Batch time: 0.67ms | Samples/sec: 1147.72
#
# Training completed!
# Total training time: 0.26 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 1.0000
# Final in-context accuracy: 0.5000
# Average samples/second: 1159.80
# Average batch time: 0.83ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B1_R15_20251124_144624_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 5
# Validation tasks: 50
# Batch size: 5
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4000 | Val Loss: 0.6904 | Val Acc: 0.6000 | In-context Acc: 0.5550 | Batch time: 1.13ms | Samples/sec: 4101.61
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6904 | Val Acc: 0.6000 | In-context Acc: 0.5550 | Batch time: 0.70ms | Samples/sec: 5402.45
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6904 | Val Acc: 0.6000 | In-context Acc: 0.5550 | Batch time: 0.76ms | Samples/sec: 5215.36
#
# Training completed!
# Total training time: 0.29 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.6000
# Final in-context accuracy: 0.5550
# Average samples/second: 5242.64
# Average batch time: 0.92ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B5_R15_20251124_144624_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 10
# Validation tasks: 50
# Batch size: 10
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.6000 | Val Loss: 0.6290 | Val Acc: 0.7000 | In-context Acc: 0.6975 | Batch time: 1.79ms | Samples/sec: 5333.55
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6290 | Val Acc: 0.7000 | In-context Acc: 0.6975 | Batch time: 1.49ms | Samples/sec: 6211.49
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6290 | Val Acc: 0.7000 | In-context Acc: 0.6975 | Batch time: 1.38ms | Samples/sec: 6927.89
#
# Training completed!
# Total training time: 0.43 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7000
# Final in-context accuracy: 0.6975
# Average samples/second: 6981.03
# Average batch time: 1.39ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B10_R15_20251124_144625_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 50
# Validation tasks: 50
# Batch size: 50
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5600 | Val Loss: 0.6536 | Val Acc: 0.7000 | In-context Acc: 0.7700 | Batch time: 4.48ms | Samples/sec: 10914.71
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6536 | Val Acc: 0.7000 | In-context Acc: 0.7700 | Batch time: 3.59ms | Samples/sec: 10620.98
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6536 | Val Acc: 0.7000 | In-context Acc: 0.7700 | Batch time: 3.86ms | Samples/sec: 11006.09
#
# Training completed!
# Total training time: 1.34 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7000
# Final in-context accuracy: 0.7700
# Average samples/second: 11206.77
# Average batch time: 4.37ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B50_R15_20251124_144625_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 0.6451 | Val Acc: 0.7400 | In-context Acc: 0.8027 | Batch time: 6.44ms | Samples/sec: 15224.89
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6451 | Val Acc: 0.7400 | In-context Acc: 0.8027 | Batch time: 5.68ms | Samples/sec: 16930.20
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.6451 | Val Acc: 0.7400 | In-context Acc: 0.8027 | Batch time: 8.43ms | Samples/sec: 15451.29
#
# Training completed!
# Total training time: 1.90 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7400
# Final in-context accuracy: 0.8027
# Average samples/second: 15751.07
# Average batch time: 6.25ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B100_R15_20251124_144627_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 500
# Validation tasks: 50
# Batch size: 500
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5000 | Val Loss: 0.6406 | Val Acc: 0.8020 | In-context Acc: 0.8010 | Batch time: 29.37ms | Samples/sec: 16901.07
# Step 100/300 | Train Loss: 0.0013 | Train Acc: 1.0000 | Val Loss: 0.6071 | Val Acc: 0.8020 | In-context Acc: 0.8011 | Batch time: 37.37ms | Samples/sec: 17708.32
# Step 200/300 | Train Loss: 0.0006 | Train Acc: 1.0000 | Val Loss: 0.6003 | Val Acc: 0.8020 | In-context Acc: 0.8011 | Batch time: 29.10ms | Samples/sec: 17226.01
#
# Training completed!
# Total training time: 8.65 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8020
# Final in-context accuracy: 0.8011
# Average samples/second: 17338.20
# Average batch time: 28.73ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B500_R15_20251124_144629_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 1000
# Validation tasks: 50
# Batch size: 1000
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5050 | Val Loss: 0.6431 | Val Acc: 0.7980 | In-context Acc: 0.7994 | Batch time: 68.42ms | Samples/sec: 14570.23
# Step 100/300 | Train Loss: 0.0024 | Train Acc: 1.0000 | Val Loss: 0.5723 | Val Acc: 0.7980 | In-context Acc: 0.7994 | Batch time: 65.14ms | Samples/sec: 15001.66
# Step 200/300 | Train Loss: 0.0012 | Train Acc: 1.0000 | Val Loss: 0.5637 | Val Acc: 0.7980 | In-context Acc: 0.7994 | Batch time: 66.71ms | Samples/sec: 14979.45
#
# Training completed!
# Total training time: 19.99 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7980
# Final in-context accuracy: 0.7994
# Average samples/second: 15008.95
# Average batch time: 66.51ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B1000_R15_20251124_144638_step_300.pt

# %%
plt.figure(figsize=(8, 5))

plt.plot(Bs, train_accs, marker='o', label="Train Acc")
plt.plot(Bs, val_accs, marker='o', label="Val Acc")
plt.plot(Bs, ic_accs, marker='o', label="In-context Acc")

plt.xlabel("Number of Tasks B")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Number of Tasks: R = d^0.4")
plt.grid(True, alpha=0.4)
plt.legend()
plt.tight_layout()
plt.show()

# %%
Bs = [1, 5, 10, 50, 100, 500, 1000]
train_accs = []
val_accs = []
ic_accs = []

for B in Bs:
    d, steps, label_flip_p = 1000, 300, 0.2
    R = d ** 0.6
    params = (d, B, R, R, steps, label_flip_p)
    _, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results/", use_cuda=False)
    train_accs.append(train_acc)
    val_accs.append(val_acc)
    ic_accs.append(ic_acc)
# Out:
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 1
# Validation tasks: 50
# Batch size: 1
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 1.0000 | Val Loss: 29.1292 | Val Acc: 0.0000 | In-context Acc: 0.7750 | Batch time: 3.07ms | Samples/sec: 284.75
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 29.1292 | Val Acc: 0.0000 | In-context Acc: 0.7750 | Batch time: 0.59ms | Samples/sec: 804.65
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 29.1292 | Val Acc: 0.0000 | In-context Acc: 0.7750 | Batch time: 2.25ms | Samples/sec: 889.30
#
# Training completed!
# Total training time: 0.32 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.0000
# Final in-context accuracy: 0.7750
# Average samples/second: 939.46
# Average batch time: 1.02ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B1_R63_20251124_144347_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 5
# Validation tasks: 50
# Batch size: 5
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4000 | Val Loss: 0.0006 | Val Acc: 1.0000 | In-context Acc: 0.8500 | Batch time: 1.00ms | Samples/sec: 4625.39
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.0006 | Val Acc: 1.0000 | In-context Acc: 0.8500 | Batch time: 0.92ms | Samples/sec: 4808.20
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.0006 | Val Acc: 1.0000 | In-context Acc: 0.8500 | Batch time: 1.12ms | Samples/sec: 4583.00
#
# Training completed!
# Total training time: 0.33 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 1.0000
# Final in-context accuracy: 0.8500
# Average samples/second: 4477.84
# Average batch time: 1.08ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B5_R63_20251124_144348_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 10
# Validation tasks: 50
# Batch size: 10
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.6000 | Val Loss: 14.0680 | Val Acc: 0.8000 | In-context Acc: 0.8000 | Batch time: 1.81ms | Samples/sec: 5260.63
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 14.0680 | Val Acc: 0.8000 | In-context Acc: 0.8000 | Batch time: 1.39ms | Samples/sec: 6242.62
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 14.0680 | Val Acc: 0.8000 | In-context Acc: 0.8000 | Batch time: 2.22ms | Samples/sec: 6138.14
#
# Training completed!
# Total training time: 0.49 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8000
# Final in-context accuracy: 0.8000
# Average samples/second: 6069.83
# Average batch time: 1.61ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B10_R63_20251124_144348_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 50
# Validation tasks: 50
# Batch size: 50
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5600 | Val Loss: 9.7411 | Val Acc: 0.8000 | In-context Acc: 0.7885 | Batch time: 3.92ms | Samples/sec: 12406.98
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 9.7411 | Val Acc: 0.8000 | In-context Acc: 0.7885 | Batch time: 4.19ms | Samples/sec: 11444.47
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 9.7411 | Val Acc: 0.8000 | In-context Acc: 0.7885 | Batch time: 4.16ms | Samples/sec: 11333.82
#
# Training completed!
# Total training time: 1.29 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8000
# Final in-context accuracy: 0.7885
# Average samples/second: 11621.58
# Average batch time: 4.22ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B50_R63_20251124_144349_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 10.9908 | Val Acc: 0.7700 | In-context Acc: 0.8073 | Batch time: 6.68ms | Samples/sec: 14714.27
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 10.9908 | Val Acc: 0.7700 | In-context Acc: 0.8073 | Batch time: 6.25ms | Samples/sec: 15233.46
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 10.9908 | Val Acc: 0.7700 | In-context Acc: 0.8073 | Batch time: 5.50ms | Samples/sec: 15171.99
#
# Training completed!
# Total training time: 1.92 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7700
# Final in-context accuracy: 0.8073
# Average samples/second: 15591.57
# Average batch time: 6.32ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B100_R63_20251124_144350_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 500
# Validation tasks: 50
# Batch size: 500
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5000 | Val Loss: 9.4690 | Val Acc: 0.8020 | In-context Acc: 0.7994 | Batch time: 28.17ms | Samples/sec: 17611.29
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 9.4690 | Val Acc: 0.8020 | In-context Acc: 0.7994 | Batch time: 28.56ms | Samples/sec: 17263.91
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 9.4690 | Val Acc: 0.8020 | In-context Acc: 0.7994 | Batch time: 29.87ms | Samples/sec: 17219.56
#
# Training completed!
# Total training time: 8.78 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8020
# Final in-context accuracy: 0.7994
# Average samples/second: 17089.45
# Average batch time: 29.15ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B500_R63_20251124_144352_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 1000
# Validation tasks: 50
# Batch size: 1000
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5050 | Val Loss: 9.8168 | Val Acc: 0.7980 | In-context Acc: 0.7992 | Batch time: 73.91ms | Samples/sec: 13488.55
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 9.8168 | Val Acc: 0.7980 | In-context Acc: 0.7992 | Batch time: 70.74ms | Samples/sec: 14667.50
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 9.8168 | Val Acc: 0.7980 | In-context Acc: 0.7992 | Batch time: 64.44ms | Samples/sec: 14963.18
#
# Training completed!
# Total training time: 19.97 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7980
# Final in-context accuracy: 0.7992
# Average samples/second: 15021.11
# Average batch time: 66.46ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B1000_R63_20251124_144401_step_300.pt

# %%
plt.figure(figsize=(8, 5))

plt.plot(Bs, train_accs, marker='o', label="Train Acc")
plt.plot(Bs, val_accs, marker='o', label="Val Acc")
plt.plot(Bs, ic_accs, marker='o', label="In-context Acc")

plt.xlabel("Number of Tasks B")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Number of Tasks: R = d^0.6")
plt.grid(True, alpha=0.4)
plt.legend()
plt.tight_layout()
plt.show()

# %%
Bs = [1, 5, 10, 50, 100, 500, 1000]
train_accs = []
val_accs = []
ic_accs = []

for B in Bs:
    d, steps, label_flip_p = 1000, 300, 0.2
    R = d ** 0.8
    params = (d, B, R, R, steps, label_flip_p)
    _, train_acc, val_acc, ic_acc = run_single_experiment(params=params, base_results_dir="test_results/", use_cuda=False)
    train_accs.append(train_acc)
    val_accs.append(val_acc)
    ic_accs.append(ic_acc)
# Out:
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 1
# Validation tasks: 50
# Batch size: 1
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 1.0000 | Val Loss: 12258.6240 | Val Acc: 0.0000 | In-context Acc: 0.8000 | Batch time: 1.59ms | Samples/sec: 534.17
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 12258.6240 | Val Acc: 0.0000 | In-context Acc: 0.8000 | Batch time: 0.77ms | Samples/sec: 897.19
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 12258.6240 | Val Acc: 0.0000 | In-context Acc: 0.8000 | Batch time: 0.64ms | Samples/sec: 1059.73
#
# Training completed!
# Total training time: 0.28 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.0000
# Final in-context accuracy: 0.8000
# Average samples/second: 1085.45
# Average batch time: 0.88ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B1_R251_20251124_144441_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 5
# Validation tasks: 50
# Batch size: 5
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.4000 | Val Loss: 0.0000 | Val Acc: 1.0000 | In-context Acc: 0.8500 | Batch time: 1.04ms | Samples/sec: 4440.30
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.0000 | Val Acc: 1.0000 | In-context Acc: 0.8500 | Batch time: 1.01ms | Samples/sec: 4993.38
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.0000 | Val Acc: 1.0000 | In-context Acc: 0.8500 | Batch time: 1.02ms | Samples/sec: 4869.71
#
# Training completed!
# Total training time: 0.32 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 1.0000
# Final in-context accuracy: 0.8500
# Average samples/second: 4620.79
# Average batch time: 1.05ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B5_R251_20251124_144442_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 10
# Validation tasks: 50
# Batch size: 10
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.6000 | Val Loss: 3406.4922 | Val Acc: 0.8000 | In-context Acc: 0.8000 | Batch time: 1.47ms | Samples/sec: 6356.93
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 3406.4922 | Val Acc: 0.8000 | In-context Acc: 0.8000 | Batch time: 1.50ms | Samples/sec: 5555.76
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 3406.4922 | Val Acc: 0.8000 | In-context Acc: 0.8000 | Batch time: 1.83ms | Samples/sec: 6084.64
#
# Training completed!
# Total training time: 0.48 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8000
# Final in-context accuracy: 0.8000
# Average samples/second: 6304.76
# Average batch time: 1.54ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B10_R251_20251124_144442_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 50
# Validation tasks: 50
# Batch size: 50
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5600 | Val Loss: 2445.5415 | Val Acc: 0.8000 | In-context Acc: 0.7885 | Batch time: 4.31ms | Samples/sec: 11358.67
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 2445.5415 | Val Acc: 0.8000 | In-context Acc: 0.7885 | Batch time: 4.23ms | Samples/sec: 12186.74
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 2445.5415 | Val Acc: 0.8000 | In-context Acc: 0.7885 | Batch time: 5.28ms | Samples/sec: 11529.04
#
# Training completed!
# Total training time: 1.28 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8000
# Final in-context accuracy: 0.7885
# Average samples/second: 11758.22
# Average batch time: 4.17ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B50_R251_20251124_144443_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 100
# Validation tasks: 50
# Batch size: 100
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5400 | Val Loss: 2740.9624 | Val Acc: 0.7700 | In-context Acc: 0.8073 | Batch time: 6.29ms | Samples/sec: 15620.08
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 2740.9624 | Val Acc: 0.7700 | In-context Acc: 0.8073 | Batch time: 6.00ms | Samples/sec: 16562.34
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 2740.9624 | Val Acc: 0.7700 | In-context Acc: 0.8073 | Batch time: 5.78ms | Samples/sec: 16083.68
#
# Training completed!
# Total training time: 1.86 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7700
# Final in-context accuracy: 0.8073
# Average samples/second: 16118.69
# Average batch time: 6.11ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B100_R251_20251124_144444_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 500
# Validation tasks: 50
# Batch size: 500
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5000 | Val Loss: 2375.2104 | Val Acc: 0.8020 | In-context Acc: 0.7994 | Batch time: 31.27ms | Samples/sec: 15872.48
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 2375.2104 | Val Acc: 0.8020 | In-context Acc: 0.7994 | Batch time: 27.29ms | Samples/sec: 17993.96
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 2375.2104 | Val Acc: 0.8020 | In-context Acc: 0.7994 | Batch time: 27.04ms | Samples/sec: 17956.94
#
# Training completed!
# Total training time: 8.36 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.8020
# Final in-context accuracy: 0.7994
# Average samples/second: 17938.36
# Average batch time: 27.77ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B500_R251_20251124_144446_step_300.pt
# Using device: cpu
#
# Starting training on cpu
# Input dimension (d): 1000
# Training tasks: 1000
# Validation tasks: 50
# Batch size: 1000
# --------------------------------------------------
# Step 0/300 | Train Loss: 0.6931 | Train Acc: 0.5050 | Val Loss: 2464.1165 | Val Acc: 0.7980 | In-context Acc: 0.7992 | Batch time: 68.77ms | Samples/sec: 14477.00
# Step 100/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 2464.1165 | Val Acc: 0.7980 | In-context Acc: 0.7992 | Batch time: 63.61ms | Samples/sec: 15167.07
# Step 200/300 | Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 2464.1165 | Val Acc: 0.7980 | In-context Acc: 0.7992 | Batch time: 64.36ms | Samples/sec: 15358.77
#
# Training completed!
# Total training time: 19.50 seconds
# Final train accuracy: 1.0000
# Final validation accuracy: 0.7980
# Final in-context accuracy: 0.7992
# Average samples/second: 15386.27
# Average batch time: 64.89ms
# Saving checkpoint at checkpoints/checkpoint_d1000_B1000_R251_20251124_144455_step_300.pt

# %%
plt.figure(figsize=(8, 5))

plt.plot(Bs, train_accs, marker='o', label="Train Acc")
plt.plot(Bs, val_accs, marker='o', label="Val Acc")
plt.plot(Bs, ic_accs, marker='o', label="In-context Acc")

plt.xlabel("Number of Tasks B")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Number of Tasks: R = d^0.8")
plt.grid(True, alpha=0.4)
plt.legend()
plt.tight_layout()
plt.show()
